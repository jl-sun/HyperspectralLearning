# %%
import matplotlib.pyplot as plt
import numpy as np
from dataset import SpectralDataset


# Read Spectral Image (SI) and Ground Truth (GT)
data = SpectralDataset('airport1')
si = data.image
obj = data.objects
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'map', 'data'])

# %%
print("Total max:", np.max(si))
print("Total min:", np.min(si))
max_arr = []
min_arr = []
for i in range(0, 103):
    img = si[:, :, i]
    max_arr.append(np.max(img))
    min_arr.append(np.min(img))
plt.plot(min_arr, 'r-')
plt.plot(max_arr, 'b-')
# plt.plot(np.array(max_arr)-np.array(min_arr), 'g--')
# Out:
# Total max: 6604
# Total min: 0
